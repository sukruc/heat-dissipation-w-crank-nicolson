# %% [markdown]
# ## Crank-Nicolson sonlu fark şemasının *Konjuge Gradyen Metodu* ile çözümü

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import sys

from heat_utils import initialize, calculate, propagate, heatmap
del sys.modules['heat_utils']
from heat_utils import initialize, calculate, propagate, heatmap

# %%
metadata = pickle.load(open('test.pk','rb'))

# %%
X = metadata['X']
Y = metadata['Y']
dx = metadata['dx']
dt = metadata['dt']
T = metadata['data']
dt
# Out:
# 1

# %%
T[:,:,3600].reshape(nx,ny).shape
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-162-9093c62687e2> in <module>
# ----> 1 T[:,:,3600].reshape(nx,ny).shape
#
# ValueError: cannot reshape array of size 500 into shape (41,11)

# %%
cmap_intervals = np.arange(0,20000,1000)

# %%
mx = np.linspace(0, X, nx)
my = np.linspace(0, Y, ny)
vx, vy = np.meshgrid(mx,my)
plt.figure(figsize=(12,8))
plt.contourf(vx, vy, np.flipud((T[:,:,3600]).reshape(len(my),len(mx))), cmap='jet', alpha = 1,
            antialiased=True)
plt.colorbar()
plt.title('5 dk Sonunda Sıcaklık Dağılımı')
plt.xlabel('x [m]')
plt.ylabel('y [m]')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-172-69864263dc99> in <module>
#       3 vx, vy = np.meshgrid(mx,my)
#       4 plt.figure(figsize=(12,8))
# ----> 5 plt.contourf(vx, vy, np.flipud((T[:,:,3600]).reshape(len(my),len(mx))), cmap='jet', alpha = 1,
#       6             antialiased=True)
#       7 plt.colorbar()
#
# ValueError: cannot reshape array of size 500 into shape (11,41)

# %%
cm = plt.cm.get_cmap('jet')
fig, ax = plt.subplots(2,2, figsize=(12,8), sharex=True, sharey=True)
heatmap(X, Y, T, dx, dt, 300, ax[0,0])
heatmap(X, Y, T, dx, dt, 900, ax[0,1])
heatmap(X, Y, T, dx, dt, 1800, ax[1,0])
heatmap(X, Y, T, dx, dt, 3600, ax[1,1])

# %%
heatmap(X, Y, T, dx, dt, 300)

# %%
heatmap(X, Y, T, dx, dt, 900)

# %%
heatmap(X, Y, T, dx, dt, 1800)

# %%
a = heatmap(X, Y, T, dx, dt, 3600)

# %%
a.savefig('a.png')

# %%
for i,j in enumerate(np.arange(0,3600,100)):
    fig = heatmap(X, Y, T, dx, dt, j)
    fig.savefig('imgs/heatmap_%03d.jpg' % i)
    plt.close('all')

# %%
'%03d' % 5
# Out:
# '005'
