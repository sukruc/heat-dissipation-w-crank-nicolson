# %% [markdown]
# ## Crank-Nicolson sonlu fark şemasının *Konjuge Gradyen Metodu* ile çözümü

# %%
import numpy as np
import matplotlib.pyplot as plt
import pickle
import sys

from heatutils import initialize, calculate, propagate, heatmap
del sys.modules['heatutils']
from heatutils import initialize, calculate, propagate, heatmap

# %%
metadata = pickle.load(open('test.pk','rb'))

# %%
X = metadata['X']
Y = metadata['Y']
dx = metadata['dx']
dt = metadata['dt']
T = metadata['data']

# %%
cm = plt.cm.get_cmap('jet')
fig, ax = plt.subplots(2,2, figsize=(12,8), sharex=True, sharey=True)
heatmap(X, Y, T, dx, dt, 300, ax[0,0])
heatmap(X, Y, T, dx, dt, 900, ax[0,1])
heatmap(X, Y, T, dx, dt, 1800, ax[1,0])
heatmap(X, Y, T, dx, dt, 3600, ax[1,1])

# %%
_ = heatmap(X, Y, T, dx, dt, 300)

# %%
_ = heatmap(X, Y, T, dx, dt, 900)

# %%
_ = heatmap(X, Y, T, dx, dt, 1800)

# %%
_ = heatmap(X, Y, T, dx, dt, 3600)
